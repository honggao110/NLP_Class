# %% [markdown]
# ## NLP Homework 1
#
# ### IMDB Movie Review Sentiment Analysis

# %% [markdown]
# #### Data Preprocessing
#
# First, Load libaries and read in datasets.

# %%
import random
import spacy
import string
import os

# %%
filepath = "aclImdb"
train_p_name = os.listdir(filepath + "/train/pos")
train_n_name = os.listdir(filepath + "/train/neg")
test_p_name = os.listdir(filepath + "/test/pos")
test_n_name = os.listdir(filepath + "/test/neg")

# %%
def readtxtfile(filepath, filenames):
    filelist = []
    for i in filenames:
        file = open(filepath + i, "r")
        filelist.append(file.read())
        file.close()
    return filelist

# %%
train_pos = readtxtfile(filepath + "/train/pos/", train_p_name)

# %%
len(train_pos)
# Out:
# 12500

# %%
train_pos[5]
# Out:
# 'I saw the movie with two grown children. Although it was not as clever as Shrek, I thought it was rather good. In a movie theatre surrounded by children who were on spring break, there was not a sound so I know the children all liked it. There parents also seemed engaged. The death and apparent death of characters brought about the appropriate gasps and comments. Hopefully people realize this movie was made for kids. As such, it was successful although I liked it too. Personally I liked the Scrat!!'

# %%
train_neg = readtxtfile(filepath + "/train/neg/", train_n_name)
test_pos = readtxtfile(filepath + "/test/pos/", test_p_name)
test_neg = readtxtfile(filepath + "/test/neg/", test_n_name)

# %%
train_label_p = [1] * len(train_pos)
train_label_n = [0] * len(train_neg)
test_label_p = [1] * len(test_pos)
test_label_n = [0] * len(test_neg)

# %%
len(train_label_n)
# Out:
# 12500

# %% [markdown]
# split train data into train set and validation set. Train dataset has 10,000 positive reviews and 10,000 negative reviews. Test data has 2,500 each.

# %%
train_split = 10000

train_data_p = train_pos[:train_split]
train_data_p_label = train_label_p[:train_split]
train_data_n = train_neg[:train_split]
train_data_n_label = train_label_n[:train_split]


val_data_p = train_pos[train_split:]
val_data_p_label = train_label_p[train_split:]
val_data_n = train_neg[train_split:]
val_data_n_label = train_label_n[train_split:]

# %%
len(train_data_p)
# Out:
# 10000

# %%
train_data = train_data_p + train_data_n
train_label = train_data_p_label + train_data_n_label
val_data = val_data_p + val_data_n
val_label = val_data_p_label + val_data_n_label

# %%
train_data[1]
# Out:
# 'Bizarre horror movie filled with famous faces but stolen by Cristina Raines (later of TV\'s "Flamingo Road") as a pretty but somewhat unstable model with a gummy smile who is slated to pay for her attempted suicides by guarding the Gateway to Hell! The scenes with Raines modeling are very well captured, the mood music is perfect, Deborah Raffin is charming as Cristina\'s pal, but when Raines moves into a creepy Brooklyn Heights brownstone (inhabited by a blind priest on the top floor), things really start cooking. The neighbors, including a fantastically wicked Burgess Meredith and kinky couple Sylvia Miles & Beverly D\'Angelo, are a diabolical lot, and Eli Wallach is great fun as a wily police detective. The movie is nearly a cross-pollination of "Rosemary\'s Baby" and "The Exorcist"--but what a combination! Based on the best-seller by Jeffrey Konvitz, "The Sentinel" is entertainingly spooky, full of shocks brought off well by director Michael Winner, who mounts a thoughtfully downbeat ending with skill. ***1/2 from ****'

# %% [markdown]
# Combine test reviews and test labels into test set.

# %%
test_data = test_pos + test_neg
test_label = test_label_p + test_label_n

# %%
len(test_data)
# Out:
# 25000

# %% [markdown]
# #### Tokenize

# %% [markdown]
# Tokenize the dataset.

# %%
import spacy
import string

# code from Lab 3
# Load English tokenizer, tagger, parser, NER and word vectors
tokenizer = spacy.load('en_core_web_sm')
punctuations = string.punctuation

# lowercase and remove punctuation
def tokenize(sent):
  tokens = tokenizer(sent)
  return [token.text.lower() for token in tokens if (token.text not in punctuations)]

# %%
def tokenize_dataset(dataset):
    token_dataset = []
    # we are keeping track of all tokens in dataset 
    # in order to create vocabulary later
    all_tokens = []
    
    for sample in dataset:
        tokens = tokenize(sample)
        token_dataset.append(tokens)
        all_tokens += tokens

    return token_dataset, all_tokens

# %%
import pickle as pkl
print ("Tokenizing val data")
val_data_tokens, _ = tokenize_dataset(val_data)
pkl.dump(val_data_tokens, open("val_data_tokens.p", "wb"))
# Out:
# Tokenizing val data

# %%
# test set tokens
print ("Tokenizing test data")
test_data_tokens, _ = tokenize_dataset(test_data)
pkl.dump(test_data_tokens, open("test_data_tokens.p", "wb"))

# train set tokens
print ("Tokenizing train data")
train_data_tokens, all_train_tokens = tokenize_dataset(train_data)
pkl.dump(train_data_tokens, open("train_data_tokens.p", "wb"))
pkl.dump(all_train_tokens, open("all_train_tokens.p", "wb"))
# Out:
# Tokenizing test data
# Tokenizing train data

# %%
len(train_data_tokens)
# Out:
# 20000

# %% [markdown]
# Create vocabulary in the training set.

# %%
from collections import Counter

max_vocab_size = 10000
# save index 0 for unk and 1 for pad
PAD_IDX = 0
UNK_IDX = 1

def build_vocab(all_tokens):
    # Returns:
    # id2token: list of tokens, where id2token[i] returns token that corresponds to token i
    # token2id: dictionary where keys represent tokens and corresponding values represent indices
    token_counter = Counter(all_tokens)
    vocab, count = zip(*token_counter.most_common(max_vocab_size))
    id2token = list(vocab)
    token2id = dict(zip(vocab, range(2,2+len(vocab)))) 
    id2token = ['<pad>', '<unk>'] + id2token
    token2id['<pad>'] = PAD_IDX 
    token2id['<unk>'] = UNK_IDX
    return token2id, id2token

token2id, id2token = build_vocab(all_train_tokens)

# %%
token2id
# Out:
# {'the': 2,
#  'and': 3,
#  'a': 4,
#  'of': 5,
#  'to': 6,
#  'is': 7,
#  'it': 8,
#  'in': 9,
#  'i': 10,
#  'this': 11,
#  'that': 12,
#  "'s": 13,
#  '/><br': 14,
#  'was': 15,
#  'as': 16,
#  'for': 17,
#  'with': 18,
#  'movie': 19,
#  'but': 20,
#  'film': 21,
#  'you': 22,
#  'on': 23,
#  "n't": 24,
#  'not': 25,
#  'are': 26,
#  'he': 27,
#  'his': 28,
#  'have': 29,
#  'be': 30,
#  'one': 31,
#  'at': 32,
#  'all': 33,
#  'they': 34,
#  'by': 35,
#  'an': 36,
#  'who': 37,
#  'from': 38,
#  'so': 39,
#  'like': 40,
#  'her': 41,
#  'there': 42,
#  'or': 43,
#  'just': 44,
#  'about': 45,
#  'do': 46,
#  'has': 47,
#  'out': 48,
#  'what': 49,
#  'if': 50,
#  'some': 51,
#  'good': 52,
#  'she': 53,
#  'very': 54,
#  'when': 55,
#  'more': 56,
#  'up': 57,
#  'would': 58,
#  'no': 59,
#  'even': 60,
#  'time': 61,
#  'can': 62,
#  'my': 63,
#  'which': 64,
#  'only': 65,
#  'really': 66,
#  'story': 67,
#  'their': 68,
#  'had': 69,
#  'see': 70,
#  'were': 71,
#  'we': 72,
#  'me': 73,
#  'did': 74,
#  'does': 75,
#  'well': 76,
#  '...': 77,
#  'than': 78,
#  'much': 79,
#  'could': 80,
#  'get': 81,
#  'been': 82,
#  'into': 83,
#  'people': 84,
#  'will': 85,
#  'bad': 86,
#  'other': 87,
#  'because': 88,
#  'also': 89,
#  'great': 90,
#  'first': 91,
#  'him': 92,
#  'how': 93,
#  'most': 94,
#  'made': 95,
#  'its': 96,
#  'make': 97,
#  'then': 98,
#  'way': 99,
#  'br': 100,
#  'them': 101,
#  'any': 102,
#  'too': 103,
#  'movies': 104,
#  'after': 105,
#  '/>the': 106,
#  'think': 107,
#  'characters': 108,
#  'character': 109,
#  'two': 110,
#  'films': 111,
#  'many': 112,
#  'watch': 113,
#  'being': 114,
#  'seen': 115,
#  'life': 116,
#  'never': 117,
#  'plot': 118,
#  'best': 119,
#  'love': 120,
#  'little': 121,
#  'where': 122,
#  'acting': 123,
#  'over': 124,
#  'show': 125,
#  'know': 126,
#  'off': 127,
#  'ever': 128,
#  'man': 129,
#  'your': 130,
#  'better': 131,
#  'still': 132,
#  'here': 133,
#  'end': 134,
#  'these': 135,
#  'should': 136,
#  'say': 137,
#  'scene': 138,
#  'why': 139,
#  'scenes': 140,
#  'such': 141,
#  'while': 142,
#  'go': 143,
#  'something': 144,
#  "'ve": 145,
#  'back': 146,
#  'through': 147,
#  'those': 148,
#  'real': 149,
#  'old': 150,
#  'watching': 151,
#  'years': 152,
#  'though': 153,
#  'thing': 154,
#  "'m": 155,
#  'actors': 156,
#  'new': 157,
#  'director': 158,
#  'work': 159,
#  'now': 160,
#  'before': 161,
#  'makes': 162,
#  'nothing': 163,
#  'actually': 164,
#  'find': 165,
#  'funny': 166,
#  'another': 167,
#  'look': 168,
#  'going': 169,
#  'few': 170,
#  'part': 171,
#  'same': 172,
#  '--': 173,
#  'lot': 174,
#  'every': 175,
#  'us': 176,
#  'again': 177,
#  'world': 178,
#  'quite': 179,
#  'cast': 180,
#  '/>i': 181,
#  'got': 182,
#  'ca': 183,
#  'want': 184,
#  'young': 185,
#  'things': 186,
#  'horror': 187,
#  "'re": 188,
#  'pretty': 189,
#  'down': 190,
#  'around': 191,
#  'seems': 192,
#  'fact': 193,
#  'big': 194,
#  'take': 195,
#  'enough': 196,
#  'between': 197,
#  'thought': 198,
#  'long': 199,
#  'series': 200,
#  'original': 201,
#  'may': 202,
#  'give': 203,
#  'both': 204,
#  'action': 205,
#  'own': 206,
#  'always': 207,
#  'however': 208,
#  'must': 209,
#  'right': 210,
#  'without': 211,
#  'gets': 212,
#  'family': 213,
#  'come': 214,
#  'point': 215,
#  'saw': 216,
#  'comedy': 217,
#  'times': 218,
#  'almost': 219,
#  'least': 220,
#  'role': 221,
#  'interesting': 222,
#  'guy': 223,
#  'whole': 224,
#  'bit': 225,
#  'done': 226,
#  'music': 227,
#  'far': 228,
#  'making': 229,
#  'might': 230,
#  'script': 231,
#  'feel': 232,
#  'last': 233,
#  'anything': 234,
#  'minutes': 235,
#  'since': 236,
#  'probably': 237,
#  'woman': 238,
#  'performance': 239,
#  'kind': 240,
#  'girl': 241,
#  'tv': 242,
#  'am': 243,
#  "'ll": 244,
#  'rather': 245,
#  'worst': 246,
#  'away': 247,
#  'day': 248,
#  'yet': 249,
#  'hard': 250,
#  'sure': 251,
#  'fun': 252,
#  'found': 253,
#  'each': 254,
#  'our': 255,
#  'having': 256,
#  'comes': 257,
#  'anyone': 258,
#  'played': 259,
#  'especially': 260,
#  'believe': 261,
#  'goes': 262,
#  'trying': 263,
#  'looking': 264,
#  'course': 265,
#  'set': 266,
#  'different': 267,
#  'place': 268,
#  'book': 269,
#  'actor': 270,
#  'looks': 271,
#  'screen': 272,
#  'although': 273,
#  'put': 274,
#  'money': 275,
#  'three': 276,
#  'someone': 277,
#  'everything': 278,
#  '/>this': 279,
#  'ending': 280,
#  'true': 281,
#  'reason': 282,
#  'once': 283,
#  'sense': 284,
#  'shows': 285,
#  'dvd': 286,
#  'main': 287,
#  'worth': 288,
#  'let': 289,
#  'job': 290,
#  'maybe': 291,
#  'plays': 292,
#  'everyone': 293,
#  'play': 294,
#  'watched': 295,
#  'american': 296,
#  'said': 297,
#  'takes': 298,
#  'effects': 299,
#  'together': 300,
#  'high': 301,
#  'house': 302,
#  'wife': 303,
#  'seem': 304,
#  'john': 305,
#  'audience': 306,
#  'beautiful': 307,
#  '10': 308,
#  "'d": 309,
#  'night': 310,
#  'himself': 311,
#  'later': 312,
#  '2': 313,
#  'during': 314,
#  'year': 315,
#  'instead': 316,
#  'left': 317,
#  'special': 318,
#  'father': 319,
#  'half': 320,
#  'star': 321,
#  'version': 322,
#  'war': 323,
#  'seeing': 324,
#  'shot': 325,
#  'idea': 326,
#  'black': 327,
#  'excellent': 328,
#  'nice': 329,
#  'less': 330,
#  'read': 331,
#  'mind': 332,
#  'else': 333,
#  'men': 334,
#  'simply': 335,
#  'home': 336,
#  'completely': 337,
#  'second': 338,
#  'hollywood': 339,
#  'dead': 340,
#  'fan': 341,
#  'death': 342,
#  'help': 343,
#  'used': 344,
#  'poor': 345,
#  'line': 346,
#  'classic': 347,
#  'low': 348,
#  'need': 349,
#  'use': 350,
#  'budget': 351,
#  'top': 352,
#  'women': 353,
#  'short': 354,
#  'given': 355,
#  'either': 356,
#  'until': 357,
#  'kids': 358,
#  'performances': 359,
#  'try': 360,
#  'full': 361,
#  'friends': 362,
#  'enjoy': 363,
#  'rest': 364,
#  'camera': 365,
#  'production': 366,
#  'truly': 367,
#  'along': 368,
#  'next': 369,
#  'video': 370,
#  'sex': 371,
#  'boring': 372,
#  'wrong': 373,
#  'tell': 374,
#  '..': 375,
#  'start': 376,
#  'remember': 377,
#  'awful': 378,
#  'couple': 379,
#  'small': 380,
#  'came': 381,
#  'mean': 382,
#  '/>it': 383,
#  'school': 384,
#  'face': 385,
#  'keep': 386,
#  'recommend': 387,
#  'stars': 388,
#  'episode': 389,
#  'moments': 390,
#  'often': 391,
#  'getting': 392,
#  'wonderful': 393,
#  'playing': 394,
#  'early': 395,
#  'understand': 396,
#  'gives': 397,
#  'stupid': 398,
#  'name': 399,
#  'human': 400,
#  'perhaps': 401,
#  'doing': 402,
#  'perfect': 403,
#  'piece': 404,
#  'terrible': 405,
#  'written': 406,
#  'person': 407,
#  'become': 408,
#  'lost': 409,
#  'supposed': 410,
#  'felt': 411,
#  'others': 412,
#  'live': 413,
#  'definitely': 414,
#  'itself': 415,
#  'dialogue': 416,
#  'case': 417,
#  'lines': 418,
#  'children': 419,
#  'boy': 420,
#  'liked': 421,
#  'sort': 422,
#  'style': 423,
#  'head': 424,
#  'against': 425,
#  'entire': 426,
#  'mother': 427,
#  'went': 428,
#  'white': 429,
#  'absolutely': 430,
#  'evil': 431,
#  'problem': 432,
#  'called': 433,
#  'waste': 434,
#  'finally': 435,
#  'cinema': 436,
#  'certainly': 437,
#  'picture': 438,
#  'several': 439,
#  'loved': 440,
#  'hope': 441,
#  'title': 442,
#  'fans': 443,
#  'friend': 444,
#  'yes': 445,
#  'worse': 446,
#  'lives': 447,
#  'under': 448,
#  'based': 449,
#  'entertaining': 450,
#  'killer': 451,
#  'seemed': 452,
#  'drama': 453,
#  'beginning': 454,
#  'becomes': 455,
#  'dark': 456,
#  'son': 457,
#  'care': 458,
#  'example': 459,
#  'already': 460,
#  'laugh': 461,
#  'wanted': 462,
#  '\x96': 463,
#  'direction': 464,
#  'child': 465,
#  'throughout': 466,
#  '3': 467,
#  'michael': 468,
#  'guys': 469,
#  'sound': 470,
#  'lead': 471,
#  'turn': 472,
#  'writing': 473,
#  'humor': 474,
#  'wants': 475,
#  'past': 476,
#  'final': 477,
#  'totally': 478,
#  '<br': 479,
#  'able': 480,
#  'amazing': 481,
#  'close': 482,
#  'oh': 483,
#  'wo': 484,
#  'heart': 485,
#  'quality': 486,
#  'guess': 487,
#  'tries': 488,
#  'fine': 489,
#  'game': 490,
#  'side': 491,
#  'art': 492,
#  'enjoyed': 493,
#  'history': 494,
#  'behind': 495,
#  'turns': 496,
#  'viewer': 497,
#  'town': 498,
#  'works': 499,
#  'hand': 500,
#  'flick': 501,
#  'favorite': 502,
#  'days': 503,
#  'unfortunately': 504,
#  'gave': 505,
#  'themselves': 506,
#  '1': 507,
#  'kill': 508,
#  'city': 509,
#  'today': 510,
#  'despite': 511,
#  'kid': 512,
#  'car': 513,
#  'act': 514,
#  'soon': 515,
#  'genre': 516,
#  'run': 517,
#  'god': 518,
#  'sometimes': 519,
#  'actress': 520,
#  'starts': 521,
#  'horrible': 522,
#  'expect': 523,
#  'girls': 524,
#  'parts': 525,
#  '....': 526,
#  'blood': 527,
#  'eyes': 528,
#  'slow': 529,
#  'thinking': 530,
#  'brilliant': 531,
#  'late': 532,
#  'obviously': 533,
#  'self': 534,
#  'directed': 535,
#  'stories': 536,
#  'decent': 537,
#  'voice': 538,
#  'fight': 539,
#  'feeling': 540,
#  'heard': 541,
#  'myself': 542,
#  'matter': 543,
#  'stuff': 544,
#  'writer': 545,
#  'hit': 546,
#  'took': 547,
#  'stop': 548,
#  'except': 549,
#  'etc': 550,
#  'killed': 551,
#  'hour': 552,
#  'brother': 553,
#  'type': 554,
#  'overall': 555,
#  'highly': 556,
#  'daughter': 557,
#  'says': 558,
#  'age': 559,
#  'obvious': 560,
#  'police': 561,
#  'hero': 562,
#  'happened': 563,
#  'leave': 564,
#  'strong': 565,
#  'roles': 566,
#  'involved': 567,
#  'violence': 568,
#  'particularly': 569,
#  'extremely': 570,
#  'james': 571,
#  'happens': 572,
#  'known': 573,
#  'moment': 574,
#  'living': 575,
#  'simple': 576,
#  'including': 577,
#  'told': 578,
#  'coming': 579,
#  'chance': 580,
#  'murder': 581,
#  'alone': 582,
#  'wonder': 583,
#  'mr.': 584,
#  'group': 585,
#  'attempt': 586,
#  'gore': 587,
#  'happen': 588,
#  'cut': 589,
#  'lack': 590,
#  'complete': 591,
#  'save': 592,
#  'husband': 593,
#  'ago': 594,
#  'exactly': 595,
#  'score': 596,
#  'looked': 597,
#  '/>in': 598,
#  'number': 599,
#  '/>there': 600,
#  'experience': 601,
#  'hell': 602,
#  'whose': 603,
#  'career': 604,
#  'released': 605,
#  'across': 606,
#  'david': 607,
#  'serious': 608,
#  'taken': 609,
#  'song': 610,
#  'somewhat': 611,
#  'running': 612,
#  'opening': 613,
#  'english': 614,
#  'sad': 615,
#  'ends': 616,
#  'middle': 617,
#  'interest': 618,
#  'none': 619,
#  'finds': 620,
#  'power': 621,
#  'ones': 622,
#  'musical': 623,
#  'crap': 624,
#  'hours': 625,
#  'ridiculous': 626,
#  'shown': 627,
#  'relationship': 628,
#  'body': 629,
#  'novel': 630,
#  'huge': 631,
#  'hilarious': 632,
#  'light': 633,
#  'documentary': 634,
#  'wish': 635,
#  'cinematography': 636,
#  'yourself': 637,
#  'important': 638,
#  'annoying': 639,
#  'call': 640,
#  'usual': 641,
#  'shots': 642,
#  'scary': 643,
#  'seriously': 644,
#  'level': 645,
#  'talking': 646,
#  'jokes': 647,
#  'possible': 648,
#  'change': 649,
#  'reality': 650,
#  'order': 651,
#  'king': 652,
#  'usually': 653,
#  'please': 654,
#  'view': 655,
#  'happy': 656,
#  'started': 657,
#  'opinion': 658,
#  'five': 659,
#  'taking': 660,
#  'strange': 661,
#  'female': 662,
#  'saying': 663,
#  'room': 664,
#  'ok': 665,
#  'mostly': 666,
#  'robert': 667,
#  'episodes': 668,
#  'country': 669,
#  'cool': 670,
#  'b': 671,
#  'apparently': 672,
#  '/>if': 673,
#  'single': 674,
#  'turned': 675,
#  'earth': 676,
#  'word': 677,
#  'non': 678,
#  'major': 679,
#  'modern': 680,
#  'knows': 681,
#  'clearly': 682,
#  'talent': 683,
#  'comic': 684,
#  '5': 685,
#  'class': 686,
#  'four': 687,
#  'supporting': 688,
#  '/>but': 689,
#  'easily': 690,
#  'television': 691,
#  'british': 692,
#  'jack': 693,
#  'knew': 694,
#  'songs': 695,
#  'attention': 696,
#  'events': 697,
#  'local': 698,
#  'due': 699,
#  'tells': 700,
#  'thriller': 701,
#  'cheap': 702,
#  'romantic': 703,
#  'similar': 704,
#  'sequence': 705,
#  'silly': 706,
#  'rock': 707,
#  'upon': 708,
#  'problems': 709,
#  'words': 710,
#  'bring': 711,
#  'basically': 712,
#  'moving': 713,
#  '4': 714,
#  'sets': 715,
#  'straight': 716,
#  'message': 717,
#  'falls': 718,
#  'it.<br': 719,
#  'nearly': 720,
#  'paul': 721,
#  'theater': 722,
#  'fast': 723,
#  'lady': 724,
#  'needs': 725,
#  'miss': 726,
#  'beyond': 727,
#  'future': 728,
#  'near': 729,
#  'disappointed': 730,
#  'entertainment': 731,
#  'anyway': 732,
#  'talk': 733,
#  'george': 734,
#  'appears': 735,
#  'rating': 736,
#  'mystery': 737,
#  'team': 738,
#  'easy': 739,
#  'within': 740,
#  'predictable': 741,
#  'red': 742,
#  'using': 743,
#  'theme': 744,
#  'giving': 745,
#  'points': 746,
#  'york': 747,
#  'mention': 748,
#  'release': 749,
#  'hate': 750,
#  'whether': 751,
#  'named': 752,
#  'richard': 753,
#  'dull': 754,
#  'fall': 755,
#  'sister': 756,
#  'stand': 757,
#  'working': 758,
#  'ten': 759,
#  'among': 760,
#  'fantastic': 761,
#  'enjoyable': 762,
#  'oscar': 763,
#  'sequel': 764,
#  'showing': 765,
#  'add': 766,
#  'tale': 767,
#  'follow': 768,
#  'herself': 769,
#  'begins': 770,
#  'lee': 771,
#  'review': 772,
#  'french': 773,
#  'famous': 774,
#  'eye': 775,
#  'viewers': 776,
#  'lots': 777,
#  'animation': 778,
#  'typical': 779,
#  'bunch': 780,
#  'actual': 781,
#  'die': 782,
#  'surprised': 783,
#  'storyline': 784,
#  'feels': 785,
#  'feature': 786,
#  '/>and': 787,
#  'above': 788,
#  'ways': 789,
#  'weak': 790,
#  'tom': 791,
#  'comments': 792,
#  'effort': 793,
#  'elements': 794,
#  'form': 795,
#  'clear': 796,
#  'stay': 797,
#  'tried': 798,
#  'crime': 799,
#  're': 800,
#  'somehow': 801,
#  'gone': 802,
#  'movie.<br': 803,
#  'peter': 804,
#  'hear': 805,
#  'kept': 806,
#  'parents': 807,
#  'sorry': 808,
#  'soundtrack': 809,
#  'certain': 810,
#  'season': 811,
#  'greatest': 812,
#  'zombie': 813,
#  'editing': 814,
#  'dialog': 815,
#  'material': 816,
#  'general': 817,
#  'doubt': 818,
#  'space': 819,
#  'realistic': 820,
#  'lame': 821,
#  'buy': 822,
#  'filmed': 823,
#  'check': 824,
#  'move': 825,
#  'leads': 826,
#  '/>a': 827,
#  'brought': 828,
#  'sequences': 829,
#  'dog': 830,
#  'means': 831,
#  'america': 832,
#  'disney': 833,
#  'viewing': 834,
#  'figure': 835,
#  'sexual': 836,
#  'de': 837,
#  'imagine': 838,
#  'period': 839,
#  'eventually': 840,
#  'learn': 841,
#  'particular': 842,
#  'subject': 843,
#  'dance': 844,
#  'third': 845,
#  'poorly': 846,
#  'reviews': 847,
#  'deal': 848,
#  'forget': 849,
#  '/>as': 850,
#  'wait': 851,
#  'nor': 852,
#  'difficult': 853,
#  'film.<br': 854,
#  'decided': 855,
#  'rent': 856,
#  'minute': 857,
#  'indeed': 858,
#  'possibly': 859,
#  'average': 860,
#  'suspense': 861,
#  'premise': 862,
#  'surprise': 863,
#  'sit': 864,
#  'stage': 865,
#  'atmosphere': 866,
#  'nature': 867,
#  'whatever': 868,
#  'killing': 869,
#  'avoid': 870,
#  'leaves': 871,
#  'screenplay': 872,
#  'free': 873,
#  'truth': 874,
#  'hot': 875,
#  'begin': 876,
#  'meet': 877,
#  'expected': 878,
#  'became': 879,
#  'meets': 880,
#  'baby': 881,
#  'dream': 882,
#  'believable': 883,
#  'credits': 884,
#  'question': 885,
#  'japanese': 886,
#  'write': 887,
#  'realize': 888,
#  'reading': 889,
#  'note': 890,
#  'dramatic': 891,
#  'situation': 892,
#  'street': 893,
#  'footage': 894,
#  'deep': 895,
#  'memorable': 896,
#  'features': 897,
#  'joe': 898,
#  'crazy': 899,
#  'older': 900,
#  'forward': 901,
#  'needed': 902,
#  'girlfriend': 903,
#  'badly': 904,
#  'previous': 905,
#  'keeps': 906,
#  'comment': 907,
#  'writers': 908,
#  'emotional': 909,
#  'worked': 910,
#  'result': 911,
#  'meant': 912,
#  's': 913,
#  'beauty': 914,
#  'okay': 915,
#  'cheesy': 916,
#  'towards': 917,
#  'laughs': 918,
#  'sci': 919,
#  'fi': 920,
#  'forced': 921,
#  'directors': 922,
#  'romance': 923,
#  'ask': 924,
#  'gay': 925,
#  'male': 926,
#  'superb': 927,
#  'weird': 928,
#  'open': 929,
#  'interested': 930,
#  'quickly': 931,
#  'boys': 932,
#  'acted': 933,
#  'total': 934,
#  'whom': 935,
#  'mark': 936,
#  'unless': 937,
#  'imdb': 938,
#  'shame': 939,
#  'box': 940,
#  'fantasy': 941,
#  'otherwise': 942,
#  'brings': 943,
#  'present': 944,
#  'directing': 945,
#  'fire': 946,
#  '20': 947,
#  'creepy': 948,
#  'society': 949,
#  'business': 950,
#  'admit': 951,
#  'setting': 952,
#  'sounds': 953,
#  'unique': 954,
#  'powerful': 955,
#  'earlier': 956,
#  'plus': 957,
#  'appear': 958,
#  'create': 959,
#  'twist': 960,
#  'bill': 961,
#  'battle': 962,
#  'air': 963,
#  'political': 964,
#  'hardly': 965,
#  'perfectly': 966,
#  'doctor': 967,
#  'cop': 968,
#  'incredibly': 969,
#  'dumb': 970,
#  'break': 971,
#  'personal': 972,
#  'return': 973,
#  'inside': 974,
#  'various': 975,
#  'western': 976,
#  'christmas': 977,
#  'development': 978,
#  'monster': 979,
#  'telling': 980,
#  'leading': 981,
#  'rich': 982,
#  'casting': 983,
#  'portrayed': 984,
#  'ben': 985,
#  'outside': 986,
#  'mess': 987,
#  'front': 988,
#  'plenty': 989,
#  'fails': 990,
#  'joke': 991,
#  'manages': 992,
#  'villain': 993,
#  'fairly': 994,
#  'remake': 995,
#  'effect': 996,
#  'jane': 997,
#  'rate': 998,
#  'hands': 999,
#  'nudity': 1000,
#  'apart': 1001,
#  ...}

# %%
# check the dictionary 
random_token_id = random.randint(0, len(id2token)-1)
random_token = id2token[random_token_id]

print ("Token id {} ; token {}".format(random_token_id, id2token[random_token_id]))
print ("Token {}; token id {}".format(random_token, token2id[random_token]))
# Out:
# Token id 9061 ; token anchors
# Token anchors; token id 9061

# %%
# convert token to id in the dataset
def token2index_dataset(tokens_data):
    indices_data = []
    for tokens in tokens_data:
        index_list = [token2id[token] if token in token2id else UNK_IDX for token in tokens]
        indices_data.append(index_list)
    return indices_data

train_data_indices = token2index_dataset(train_data_tokens)
val_data_indices = token2index_dataset(val_data_tokens)
test_data_indices = token2index_dataset(test_data_tokens)

# double checking
print ("Train dataset size is {}".format(len(train_data_indices)))
print ("Val dataset size is {}".format(len(val_data_indices)))
print ("Test dataset size is {}".format(len(test_data_indices)))
# Out:
# Train dataset size is 20000
# Val dataset size is 5000
# Test dataset size is 25000

# %% [markdown]
# #### Build PyTorch Dataloader

# %%
MAX_SENTENCE_LENGTH = 200

import numpy as np
import torch
from torch.utils.data import Dataset

class NewsGroupDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """
    
    def __init__(self, data_list, target_list):
        """
        @param data_list: list of newsgroup tokens 
        @param target_list: list of newsgroup targets 

        """
        self.data_list = data_list
        self.target_list = target_list
        assert (len(self.data_list) == len(self.target_list))

    def __len__(self):
        return len(self.data_list)
        
    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        
        token_idx = self.data_list[key][:MAX_SENTENCE_LENGTH]
        label = self.target_list[key]
        return [token_idx, len(token_idx), label]

def newsgroup_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all 
    data have the same length
    """
    data_list = []
    label_list = []
    length_list = []
    #print("collate batch: ", batch[0][0])
    #batch[0][0] = batch[0][0][:MAX_SENTENCE_LENGTH]
    for datum in batch:
        label_list.append(datum[2])
        length_list.append(datum[1])
    # padding
    for datum in batch:
        padded_vec = np.pad(np.array(datum[0]), 
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[1])), 
                                mode="constant", constant_values=0)
        data_list.append(padded_vec)
    return [torch.from_numpy(np.array(data_list)), torch.LongTensor(length_list), torch.LongTensor(label_list)]

# create pytorch dataloader
#train_loader = NewsGroupDataset(train_data_indices, train_targets)
#val_loader = NewsGroupDataset(val_data_indices, val_targets)
#test_loader = NewsGroupDataset(test_data_indices, test_targets)

BATCH_SIZE = 32
train_dataset = NewsGroupDataset(train_data_indices, train_label)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=newsgroup_collate_func,
                                           shuffle=True)

val_dataset = NewsGroupDataset(val_data_indices, val_label)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=newsgroup_collate_func,
                                           shuffle=True)

test_dataset = NewsGroupDataset(test_data_indices, test_label)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=newsgroup_collate_func,
                                           shuffle=False)

#for i, (data, lengths, labels) in enumerate(train_loader):
#    print (data)
#    print (labels)
#    break

# %% [markdown]
# #### Bag-of-words Model

# %%
# First import torch related libraries
import torch
import torch.nn as nn
import torch.nn.functional as F

class BagOfWords(nn.Module):
    """
    BagOfWords classification model
    """
    def __init__(self, vocab_size, emb_dim):
        """
        @param vocab_size: size of the vocabulary. 
        @param emb_dim: size of the word embedding
        """
        super(BagOfWords, self).__init__()
        # pay attention to padding_idx 
        self.embed = nn.Embedding(vocab_size, emb_dim, padding_idx=0)
        self.linear = nn.Linear(emb_dim,20)
    
    def forward(self, data, length):
        """
        
        @param data: matrix of size (batch_size, max_sentence_length). Each row in data represents a 
            review that is represented using n-gram index. Note that they are padded to have same length.
        @param length: an int tensor of size (batch_size), which represents the non-trivial (excludes padding)
            length of each sentences in the data.
        """
        out = self.embed(data)
        out = torch.sum(out, dim=1)
        out /= length.view(length.size()[0],1).expand_as(out).float()
     
        # return logits
        out = self.linear(out.float())
        return out

emb_dim = 100 # bigger is better, 200, 500...
model = BagOfWords(len(id2token), emb_dim)

# %%
learning_rate = 0.01
num_epochs = 10 # number epoch to train

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()  
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Function for testing the model
def test_model(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data, lengths, labels in loader:
        data_batch, length_batch, label_batch = data, lengths, labels
        outputs = F.softmax(model(data_batch, length_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]
        
        total += labels.size(0)
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
    return (100 * correct / total)

for epoch in range(num_epochs):
    for i, (data, lengths, labels) in enumerate(train_loader):
        model.train()
        data_batch, length_batch, label_batch = data, lengths, labels
        optimizer.zero_grad()
        outputs = model(data_batch, length_batch)
        loss = criterion(outputs, label_batch)
        loss.backward()
        optimizer.step()
        # validate every 100 iterations
        if i > 0 and i % 100 == 0:
            # validate
            val_acc = test_model(val_loader, model)
            print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format( 
                       epoch+1, num_epochs, i+1, len(train_loader), val_acc))
# Out:
# Epoch: [1/10], Step: [101/625], Validation Acc: 75.5
# Epoch: [1/10], Step: [201/625], Validation Acc: 83.28
# Epoch: [1/10], Step: [301/625], Validation Acc: 85.1
# Epoch: [1/10], Step: [401/625], Validation Acc: 84.82
# Epoch: [1/10], Step: [501/625], Validation Acc: 86.32
# Epoch: [1/10], Step: [601/625], Validation Acc: 86.72
# Epoch: [2/10], Step: [101/625], Validation Acc: 86.52
# Epoch: [2/10], Step: [201/625], Validation Acc: 86.58
# Epoch: [2/10], Step: [301/625], Validation Acc: 86.28
# Epoch: [2/10], Step: [401/625], Validation Acc: 86.86
# Epoch: [2/10], Step: [501/625], Validation Acc: 86.78
# Epoch: [2/10], Step: [601/625], Validation Acc: 86.58
# Epoch: [3/10], Step: [101/625], Validation Acc: 86.58
# Epoch: [3/10], Step: [201/625], Validation Acc: 86.56
# Epoch: [3/10], Step: [301/625], Validation Acc: 86.36
# Epoch: [3/10], Step: [401/625], Validation Acc: 85.66
# Epoch: [3/10], Step: [501/625], Validation Acc: 86.04
# Epoch: [3/10], Step: [601/625], Validation Acc: 85.58
# Epoch: [4/10], Step: [101/625], Validation Acc: 84.9
# Epoch: [4/10], Step: [201/625], Validation Acc: 84.44
# Epoch: [4/10], Step: [301/625], Validation Acc: 85.62
# Epoch: [4/10], Step: [401/625], Validation Acc: 85.24
# Epoch: [4/10], Step: [501/625], Validation Acc: 84.94
# Epoch: [4/10], Step: [601/625], Validation Acc: 84.86
# Epoch: [5/10], Step: [101/625], Validation Acc: 85.24
# Epoch: [5/10], Step: [201/625], Validation Acc: 84.4
# Epoch: [5/10], Step: [301/625], Validation Acc: 84.68
# Epoch: [5/10], Step: [401/625], Validation Acc: 84.66
# Epoch: [5/10], Step: [501/625], Validation Acc: 84.54
# Epoch: [5/10], Step: [601/625], Validation Acc: 84.32
# Epoch: [6/10], Step: [101/625], Validation Acc: 84.1
# Epoch: [6/10], Step: [201/625], Validation Acc: 84.24
# Epoch: [6/10], Step: [301/625], Validation Acc: 84.52
# Epoch: [6/10], Step: [401/625], Validation Acc: 83.52
# Epoch: [6/10], Step: [501/625], Validation Acc: 84.72
# Epoch: [6/10], Step: [601/625], Validation Acc: 83.4
# Epoch: [7/10], Step: [101/625], Validation Acc: 84.64
# Epoch: [7/10], Step: [201/625], Validation Acc: 84.18
# Epoch: [7/10], Step: [301/625], Validation Acc: 83.86
# Epoch: [7/10], Step: [401/625], Validation Acc: 83.86
# Epoch: [7/10], Step: [501/625], Validation Acc: 83.86
# Epoch: [7/10], Step: [601/625], Validation Acc: 84.08
# Epoch: [8/10], Step: [101/625], Validation Acc: 83.82
# Epoch: [8/10], Step: [201/625], Validation Acc: 83.02
# Epoch: [8/10], Step: [301/625], Validation Acc: 83.44
# Epoch: [8/10], Step: [401/625], Validation Acc: 83.5
# Epoch: [8/10], Step: [501/625], Validation Acc: 83.34
# Epoch: [8/10], Step: [601/625], Validation Acc: 83.44
# Epoch: [9/10], Step: [101/625], Validation Acc: 83.28
# Epoch: [9/10], Step: [201/625], Validation Acc: 83.22
# Epoch: [9/10], Step: [301/625], Validation Acc: 83.06
# Epoch: [9/10], Step: [401/625], Validation Acc: 83.46
# Epoch: [9/10], Step: [501/625], Validation Acc: 83.68
# Epoch: [9/10], Step: [601/625], Validation Acc: 83.16
# Epoch: [10/10], Step: [101/625], Validation Acc: 83.02
# Epoch: [10/10], Step: [201/625], Validation Acc: 83.58
# Epoch: [10/10], Step: [301/625], Validation Acc: 83.28
# Epoch: [10/10], Step: [401/625], Validation Acc: 82.96
# Epoch: [10/10], Step: [501/625], Validation Acc: 82.9
# Epoch: [10/10], Step: [601/625], Validation Acc: 82.76

# %%
print ("After training for {} epochs".format(num_epochs))
print ("Val Acc {}".format(test_model(val_loader, model)))
print ("Test Acc {}".format(test_model(test_loader, model)))
# Out:
# After training for 10 epochs
# Val Acc 82.72
# Test Acc 80.36

# %% [markdown]
# ### Hyperparameter Tuning
#
# #### Try different Tokenize Scheme
